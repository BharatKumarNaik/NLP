# %%
sentence = '''
It classifies **real-world entities** in text into predefined categories.
NER detects **named entities** such as:
- People
- Organizations
- Locations
- Dates
- Money values
- Products (sometimes domain-specific)
'''

# %%
import nltk
words = nltk.word_tokenize(sentence)

# %%
words
# Out:
# ['It',
#  'classifies',
#  '*',
#  '*',
#  'real-world',
#  'entities',
#  '*',
#  '*',
#  'in',
#  'text',
#  'into',
#  'predefined',
#  'categories',
#  '.',
#  'NER',
#  'detects',
#  '*',
#  '*',
#  'named',
#  'entities',
#  '*',
#  '*',
#  'such',
#  'as',
#  ':',
#  '-',
#  'People',
#  '-',
#  'Organizations',
#  '-',
#  'Locations',
#  '-',
#  'Dates',
#  '-',
#  'Money',
#  'values',
#  '-',
#  'Products',
#  '(',
#  'sometimes',
#  'domain-specific',
#  ')']

# %%
tag_elements = nltk.pos_tag(words)

# %%
namedEntity = nltk.ne_chunk(tag_elements)

# %%
namedEntity
# Out:
# Tree('S', [('It', 'PRP'), ('classifies', 'VBZ'), ('*', 'JJ'), ('*', 'JJ'), ('real-world', 'NN'), ('entities', 'NNS'), ('*', 'VBP'), ('*', 'NN'), ('in', 'IN'), ('text', 'NN'), ('into', 'IN'), ('predefined', 'JJ'), ('categories', 'NNS'), ('.', '.'), Tree('ORGANIZATION', [('NER', 'NNP')]), ('detects', 'VBZ'), ('*', 'NNP'), ('*', 'NNP'), ('named', 'VBD'), ('entities', 'NNS'), ('*', 'NNP'), ('*', 'NNP'), ('such', 'JJ'), ('as', 'IN'), (':', ':'), ('-', ':'), Tree('GPE', [('People', 'NNS')]), ('-', ':'), Tree('GPE', [('Organizations', 'NNPS')]), ('-', ':'), Tree('ORGANIZATION', [('Locations', 'NNPS')]), ('-', ':'), Tree('GPE', [('Dates', 'NNPS')]), ('-', ':'), Tree('GPE', [('Money', 'NN')]), ('values', 'NNS'), ('-', ':'), ('Products', 'NNS'), ('(', '('), ('sometimes', 'RB'), ('domain-specific', 'NN'), (')', ')')])
