# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\bhara\onedrive\desktop\nlp\venv\lib\site-packages (3.9.4)
# Requirement already satisfied: click in c:\users\bhara\onedrive\desktop\nlp\venv\lib\site-packages (from nltk) (8.4.1)
# Requirement already satisfied: joblib in c:\users\bhara\onedrive\desktop\nlp\venv\lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bhara\onedrive\desktop\nlp\venv\lib\site-packages (from nltk) (2026.5.9)
# Requirement already satisfied: tqdm in c:\users\bhara\onedrive\desktop\nlp\venv\lib\site-packages (from nltk) (4.68.2)
# Requirement already satisfied: colorama in c:\users\bhara\onedrive\desktop\nlp\venv\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
corpus = '''
Hello, what'sss uppp
Intuition
This recursive approach reorders the list by pairing nodes from the front and back during the recursion unwind phase.
The idea is:
Move to the end of the list using recursion.
On the way back up (unwinding), connect the current node from the end (cur) to the corresponding node from the front (root).
Advance the front pointer (root) step-by-step as recursion unwinds.
Stop when the pointers meet or cross.
Recursion naturally processes the list from back to front, making it convenient to match front and back nodes without using extra lists.
'''

# %%
# import nltk

# nltk.download('punkt_tab', download_dir='C:/nltk_data')
# nltk.download('punkt', download_dir='C:/nltk_data')

# %%
from nltk.tokenize import sent_tokenize #Sentence Tokenization
sentence_tokens = sent_tokenize(corpus)
print(sentence_tokens)
# Out:
# ["\nHello, what'sss uppp\nIntuition\nThis recursive approach reorders the list by pairing nodes from the front and back during the recursion unwind phase.", 'The idea is:\nMove to the end of the list using recursion.', 'On the way back up (unwinding), connect the current node from the end (cur) to the corresponding node from the front (root).', 'Advance the front pointer (root) step-by-step as recursion unwinds.', 'Stop when the pointers meet or cross.', 'Recursion naturally processes the list from back to front, making it convenient to match front and back nodes without using extra lists.']

# %%
for sentence in sentence_tokens:
    print("----")
    print(sentence)
# Out:
# ----
#
# Hello, what'sss uppp
# Intuition
# This recursive approach reorders the list by pairing nodes from the front and back during the recursion unwind phase.
# ----
# The idea is:
# Move to the end of the list using recursion.
# ----
# On the way back up (unwinding), connect the current node from the end (cur) to the corresponding node from the front (root).
# ----
# Advance the front pointer (root) step-by-step as recursion unwinds.
# ----
# Stop when the pointers meet or cross.
# ----
# Recursion naturally processes the list from back to front, making it convenient to match front and back nodes without using extra lists.

# %%
from nltk.tokenize import word_tokenize
word_tokens = word_tokenize(corpus)
print(word_tokens)
# Out:
# ['Hello', ',', "what'sss", 'uppp', 'Intuition', 'This', 'recursive', 'approach', 'reorders', 'the', 'list', 'by', 'pairing', 'nodes', 'from', 'the', 'front', 'and', 'back', 'during', 'the', 'recursion', 'unwind', 'phase', '.', 'The', 'idea', 'is', ':', 'Move', 'to', 'the', 'end', 'of', 'the', 'list', 'using', 'recursion', '.', 'On', 'the', 'way', 'back', 'up', '(', 'unwinding', ')', ',', 'connect', 'the', 'current', 'node', 'from', 'the', 'end', '(', 'cur', ')', 'to', 'the', 'corresponding', 'node', 'from', 'the', 'front', '(', 'root', ')', '.', 'Advance', 'the', 'front', 'pointer', '(', 'root', ')', 'step-by-step', 'as', 'recursion', 'unwinds', '.', 'Stop', 'when', 'the', 'pointers', 'meet', 'or', 'cross', '.', 'Recursion', 'naturally', 'processes', 'the', 'list', 'from', 'back', 'to', 'front', ',', 'making', 'it', 'convenient', 'to', 'match', 'front', 'and', 'back', 'nodes', 'without', 'using', 'extra', 'lists', '.']

# %%
from nltk.tokenize import wordpunct_tokenize
# This splits even the puncutations like "what's up" -> "what","'s","up"
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  'what',
#  "'",
#  'sss',
#  'uppp',
#  'Intuition',
#  'This',
#  'recursive',
#  'approach',
#  'reorders',
#  'the',
#  'list',
#  'by',
#  'pairing',
#  'nodes',
#  'from',
#  'the',
#  'front',
#  'and',
#  'back',
#  'during',
#  'the',
#  'recursion',
#  'unwind',
#  'phase',
#  '.',
#  'The',
#  'idea',
#  'is',
#  ':',
#  'Move',
#  'to',
#  'the',
#  'end',
#  'of',
#  'the',
#  'list',
#  'using',
#  'recursion',
#  '.',
#  'On',
#  'the',
#  'way',
#  'back',
#  'up',
#  '(',
#  'unwinding',
#  '),',
#  'connect',
#  'the',
#  'current',
#  'node',
#  'from',
#  'the',
#  'end',
#  '(',
#  'cur',
#  ')',
#  'to',
#  'the',
#  'corresponding',
#  'node',
#  'from',
#  'the',
#  'front',
#  '(',
#  'root',
#  ').',
#  'Advance',
#  'the',
#  'front',
#  'pointer',
#  '(',
#  'root',
#  ')',
#  'step',
#  '-',
#  'by',
#  '-',
#  'step',
#  'as',
#  'recursion',
#  'unwinds',
#  '.',
#  'Stop',
#  'when',
#  'the',
#  'pointers',
#  'meet',
#  'or',
#  'cross',
#  '.',
#  'Recursion',
#  'naturally',
#  'processes',
#  'the',
#  'list',
#  'from',
#  'back',
#  'to',
#  'front',
#  ',',
#  'making',
#  'it',
#  'convenient',
#  'to',
#  'match',
#  'front',
#  'and',
#  'back',
#  'nodes',
#  'without',
#  'using',
#  'extra',
#  'lists',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer = TreebankWordTokenizer()

# %%
# here "." is not considered as a seperate word. but for the last word "." will be sepearate
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  ',',
#  "what'sss",
#  'uppp',
#  'Intuition',
#  'This',
#  'recursive',
#  'approach',
#  'reorders',
#  'the',
#  'list',
#  'by',
#  'pairing',
#  'nodes',
#  'from',
#  'the',
#  'front',
#  'and',
#  'back',
#  'during',
#  'the',
#  'recursion',
#  'unwind',
#  'phase.',
#  'The',
#  'idea',
#  'is',
#  ':',
#  'Move',
#  'to',
#  'the',
#  'end',
#  'of',
#  'the',
#  'list',
#  'using',
#  'recursion.',
#  'On',
#  'the',
#  'way',
#  'back',
#  'up',
#  '(',
#  'unwinding',
#  ')',
#  ',',
#  'connect',
#  'the',
#  'current',
#  'node',
#  'from',
#  'the',
#  'end',
#  '(',
#  'cur',
#  ')',
#  'to',
#  'the',
#  'corresponding',
#  'node',
#  'from',
#  'the',
#  'front',
#  '(',
#  'root',
#  ')',
#  '.',
#  'Advance',
#  'the',
#  'front',
#  'pointer',
#  '(',
#  'root',
#  ')',
#  'step-by-step',
#  'as',
#  'recursion',
#  'unwinds.',
#  'Stop',
#  'when',
#  'the',
#  'pointers',
#  'meet',
#  'or',
#  'cross.',
#  'Recursion',
#  'naturally',
#  'processes',
#  'the',
#  'list',
#  'from',
#  'back',
#  'to',
#  'front',
#  ',',
#  'making',
#  'it',
#  'convenient',
#  'to',
#  'match',
#  'front',
#  'and',
#  'back',
#  'nodes',
#  'without',
#  'using',
#  'extra',
#  'lists',
#  '.']

# %%
from nltk.tokenize import TreebankWordDetokenizer, word_tokenize

corpus = "Hello, world! How are you?"

tokens = word_tokenize(corpus)
print(tokens)

detokenizer = TreebankWordDetokenizer()
text = detokenizer.detokenize(tokens)

print(text)
# Out:
# ['Hello', ',', 'world', '!', 'How', 'are', 'you', '?']
# Hello, world! How are you?
