# %%
# Penn Treebank tag set - core POS categories
penn_tags = {
    # Nouns
    "NN": "Noun, singular or mass",
    "NNS": "Noun, plural",
    "NNP": "Proper noun, singular",
    "NNPS": "Proper noun, plural",
    # Verbs
    "VB": "Verb, base form",
    "VBD": "Verb, past tense",
    "VBG": "Verb, gerund or present participle",
    "VBN": "Verb, past participle",
    "VBP": "Verb, non-3rd person singular present",
    "VBZ": "Verb, 3rd person singular present",
    "MD": "Modal auxiliary",
    # Adjectives
    "JJ": "Adjective",
    "JJR": "Adjective, comparative",
    "JJS": "Adjective, superlative",
    # Adverbs
    "RB": "Adverb",
    "RBR": "Adverb, comparative",
    "RBS": "Adverb, superlative",
    # Pronouns and determiners
    "PRP": "Personal pronoun",
    "PRP$": "Possessive pronoun",
    "WP": "Wh-pronoun",
    "WP$": "Possessive wh-pronoun",
    "DT": "Determiner",
    "PDT": "Predeterminer",
    "WDT": "Wh-determiner",
    # Prepositions and conjunctions
    "IN": "Preposition or subordinating conjunction",
    "CC": "Coordinating conjunction",
    "TO": "to (infinitive marker)",
    "RP": "Particle",
    # Other
    "CD": "Cardinal number",
    "EX": "Existential there",
    "FW": "Foreign word",
    "POS": "Possessive ending",
    "UH": "Interjection",
    "SYM": "Symbol",
}

# %%
paragraph = '''
### Approaches to POS Tagging
1. Rule-Based Tagging
Uses manually written grammatical rules.
Example rule:
- If a word follows "the", it is likely a noun.
Advantages:
- Easy to understand
Disadvantages:
- Difficult to maintain
- Poor scalability
2. Statistical Tagging
Uses probabilities learned from annotated corpora.
Popular methods:
- Hidden Markov Models (HMM)
- Maximum Entropy Models
Example:
The word **can** can be:
- Verb: "I can swim."
- Noun: "Open the can."
The model chooses the most probable tag based on surrounding words.
3. Machine Learning and Deep Learning Approaches

Modern systems use:
- Conditional Random Fields (CRF)
- Recurrent Neural Networks (RNN)
- LSTM Networks
- Transformer-based models
These models learn contextual patterns automatically and achieve high accuracy.
'''

# %%
import nltk
sentences = nltk.tokenize.sent_tokenize(paragraph)

# %%
print(sentences)
# Out:
# ['\n### Approaches to POS Tagging\n1.', 'Rule-Based Tagging\nUses manually written grammatical rules.', 'Example rule:\n- If a word follows "the", it is likely a noun.', 'Advantages:\n- Easy to understand\nDisadvantages:\n- Difficult to maintain\n- Poor scalability\n2.', 'Statistical Tagging\nUses probabilities learned from annotated corpora.', 'Popular methods:\n- Hidden Markov Models (HMM)\n- Maximum Entropy Models\nExample:\nThe word **can** can be:\n- Verb: "I can swim."', '- Noun: "Open the can."', 'The model chooses the most probable tag based on surrounding words.', '3.', 'Machine Learning and Deep Learning Approaches\n\nModern systems use:\n- Conditional Random Fields (CRF)\n- Recurrent Neural Networks (RNN)\n- LSTM Networks\n- Transformer-based models\nThese models learn contextual patterns automatically and achieve high accuracy.']

# %%
# we will find the POS tag
for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('#', '#'), ('#', '#'), ('#', '#'), ('Approaches', 'NNP'), ('to', 'TO'), ('POS', 'NNP'), ('Tagging', 'NNP'), ('1', 'CD'), ('.', '.')]
# [('Rule-Based', 'JJ'), ('Tagging', 'NNP'), ('Uses', 'NNP'), ('manually', 'RB'), ('written', 'VBN'), ('grammatical', 'JJ'), ('rules', 'NNS'), ('.', '.')]
# [('Example', 'JJ'), ('rule', 'NN'), (':', ':'), ('-', ':'), ('If', 'IN'), ('a', 'DT'), ('word', 'NN'), ('follows', 'VBZ'), ('``', '``'), ('the', 'DT'), ("''", "''"), (',', ','), ('it', 'PRP'), ('is', 'VBZ'), ('likely', 'JJ'), ('a', 'DT'), ('noun', 'NN'), ('.', '.')]
# [('Advantages', 'NNS'), (':', ':'), ('-', ':'), ('Easy', 'NN'), ('to', 'TO'), ('understand', 'VB'), ('Disadvantages', 'NNS'), (':', ':'), ('-', ':'), ('Difficult', 'NN'), ('to', 'TO'), ('maintain', 'VB'), ('-', ':'), ('Poor', 'NNP'), ('scalability', 'NN'), ('2', 'CD'), ('.', '.')]
# [('Statistical', 'JJ'), ('Tagging', 'NNP'), ('Uses', 'NNP'), ('probabilities', 'NNS'), ('learned', 'VBD'), ('from', 'IN'), ('annotated', 'VBN'), ('corpora', 'NN'), ('.', '.')]
# [('Popular', 'JJ'), ('methods', 'NNS'), (':', ':'), ('-', ':'), ('Hidden', 'NNP'), ('Markov', 'NNP'), ('Models', 'NNP'), ('(', '('), ('HMM', 'NNP'), (')', ')'), ('-', ':'), ('Maximum', 'JJ'), ('Entropy', 'NNP'), ('Models', 'NNP'), ('Example', 'NNP'), (':', ':'), ('The', 'DT'), ('word', 'NN'), ('*', 'NNP'), ('*', 'NNP'), ('can', 'MD'), ('*', 'VB'), ('*', 'VB'), ('can', 'MD'), ('be', 'VB'), (':', ':'), ('-', ':'), ('Verb', 'NN'), (':', ':'), ('``', '``'), ('I', 'PRP'), ('can', 'MD'), ('swim', 'VB'), ('.', '.'), ("''", "''")]
# [('-', ':'), ('Noun', 'NN'), (':', ':'), ('``', '``'), ('Open', 'VB'), ('the', 'DT'), ('can', 'MD'), ('.', '.'), ("''", "''")]
# [('The', 'DT'), ('model', 'NN'), ('chooses', 'VBZ'), ('the', 'DT'), ('most', 'RBS'), ('probable', 'JJ'), ('tag', 'NN'), ('based', 'VBN'), ('on', 'IN'), ('surrounding', 'VBG'), ('words', 'NNS'), ('.', '.')]
# [('3', 'CD'), ('.', '.')]
# [('Machine', 'NN'), ('Learning', 'NNP'), ('and', 'CC'), ('Deep', 'NNP'), ('Learning', 'NNP'), ('Approaches', 'NNP'), ('Modern', 'NNP'), ('systems', 'NNS'), ('use', 'NN'), (':', ':'), ('-', ':'), ('Conditional', 'JJ'), ('Random', 'NNP'), ('Fields', 'NNP'), ('(', '('), ('CRF', 'NNP'), (')', ')'), ('-', ':'), ('Recurrent', 'JJ'), ('Neural', 'NNP'), ('Networks', 'NNP'), ('(', '('), ('RNN', 'NNP'), (')', ')'), ('-', ':'), ('LSTM', 'NN'), ('Networks', 'NNP'), ('-', ':'), ('Transformer-based', 'JJ'), ('models', 'NNS'), ('These', 'DT'), ('models', 'NNS'), ('learn', 'VBP'), ('contextual', 'JJ'), ('patterns', 'NNS'), ('automatically', 'RB'), ('and', 'CC'), ('achieve', 'RB'), ('high', 'JJ'), ('accuracy', 'NN'), ('.', '.')]
